# %%
import numpy as np
import pandas as pd

import time
import warnings

import optuna
import json
import os

from asgl import Regressor
import random
random.seed(42)
np.random.seed(42)
warnings.filterwarnings('ignore')

# %%
#Fujian data
df = pd.read_csv('res_new.csv')

a = np.array(df.values)

def split_data(data, horizon, window):
    n, m = data.shape
    X = np.zeros((n - window - horizon, window))
    Y = np.zeros((n - window - horizon,1))
    EX = np.zeros((n - window - horizon, 2))

    for i in range(n - window - horizon):
        start = i
        end = start + window

        X[i, :] = data[start:end,0]
        Y[i] = data[end + horizon - 1,0]
        EX[i,:] = data[end + horizon - 1,1:2]

    return X, Y, EX

X,Y,EX = split_data(a,1,96)
X_arg = np.hstack((X,EX))
n1=X_arg.shape[0]

train_X, train_Y = X_arg[:round(0.8 * n1)], Y[:round(0.8 * n1)]
val_X, val_Y = X_arg[round(0.8 * n1):round(0.9 * n1)], Y[round(0.8 * n1):round(0.9 * n1)]
test_X, test_Y = X_arg[round(0.9 * n1):], Y[round(0.9 * n1):]

tau_values = [round(i, 2) for i in np.arange(0.05, 1.0, 0.05)]

# %%
def pinball_loss(y_true, y_pred, tau):
    """
    Compute pinball loss for a single quantile.
    """
    errors = y_true - y_pred
    loss = np.where(errors >= 0, tau * errors, (tau - 1) * errors)
    return np.mean(loss)


def multi_quantile_pinball_loss(y_true, y_pred_all, tau_values):
    """
    Compute average pinball loss across multiple quantiles.
    """
    total_loss = 0
    n_quantiles = len(tau_values)

    for i, tau in enumerate(tau_values):
        total_loss += pinball_loss(y_true, y_pred_all[:, i], tau)

    return total_loss / n_quantiles

# %%
def objective(trial):
    """
    Optuna objective function for hyperparameter optimization.
    """
    # Define lambda search range (can be adjusted after standardization)
    lambda_val = trial.suggest_float('lambda', 0.001, 10)

    # Store validation set predictions for each quantile
    predictions_val = []

    start_time = time.time()

    for tau in tau_values:
        # Create model
        model = Regressor(model='qr', penalization='lasso', quantile=tau, lambda1=lambda_val)

        # Fit model (using standardized X)
        model.fit(train_X, train_Y)

        # Predict on validation set (using standardized X)
        y_pred_val = model.predict(val_X).reshape(-1, 1)
        predictions_val.append(y_pred_val)

    # Combine predictions for all quantiles
    predictions_val_matrix = np.hstack(predictions_val)

    # Compute average pinball loss
    current_loss = multi_quantile_pinball_loss(val_Y, predictions_val_matrix, tau_values)

    trial_time = time.time() - start_time
    trial.set_user_attr('time', trial_time)

    return current_loss

# %%
def optimize_lambda(n_trials=10):
    """
    Optimize lambda parameter using Optuna.
    """
    print(f"Starting Optuna optimization with {n_trials} trials...")

    study = optuna.create_study(
        direction='minimize',
        sampler=optuna.samplers.TPESampler(seed=42),
    )

    start_time = time.time()
    study.optimize(objective, n_trials=n_trials, show_progress_bar=True)
    total_time = time.time() - start_time

    print(f"\nOptimization complete. Total time: {total_time:.3f} seconds")
    print(f"Best lambda: {study.best_params['lambda']:.6f}")
    print(f"Best validation loss: {study.best_value:.6f}")

    results = {
        'lambda': study.best_params['lambda'],
    }

    with open("lassobest_paramsf.json", "w") as f:
        json.dump(results, f)

    return results

#Run for finding lambada
optuna_results = optimize_lambda(n_trials=30)
best_lambda=optuna_results['lambda']

# %% [markdown]
# Using hyperparameters directly, without optuna (Option B)

# %%
with open('lassobest_paramsf.json', 'r') as f:
    results = json.load(f)

best_lambda = results['lambda']
print("Best lambda:", best_lambda)
# Out:
# Best lambda: 4.130474009769122

# %%
# Evaluate on the test set using the best lambda.
def evaluate_on_test_set(lambda_val):

    print(f"\nEvaluating on test set with lambda={lambda_val:.6f}")

    test_predictions = []

    for tau in tau_values:
        model = Regressor(model='qr', penalization='lasso', quantile=tau, lambda1=lambda_val)

        model.fit(train_X, train_Y)
        y_pred_test = model.predict(test_X).reshape(-1, 1)
        test_predictions.append(y_pred_test)

    test_predictions_matrix = np.hstack(test_predictions)

    # Compute average pinball loss on test set
    test_loss = multi_quantile_pinball_loss(test_Y, test_predictions_matrix, tau_values)

    print(f"\n{'=' * 60}")
    print(f"Test set evaluation results:")
    print(f"Lambda used: {lambda_val:.6f}")
    print(f"Test set average pinball loss: {test_loss:.3f}")
    print(f"{'=' * 60}")

    return test_loss, test_predictions_matrix

# %%
test_loss, test_predictions_matrix = evaluate_on_test_set(best_lambda)
# Out:
# Evaluating on test set with lambda=4.130474
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_loss, test_predictions_matrix = evaluate_on_test_set(best_lambda)
#
# Cell In[7], line 13, in evaluate_on_test_set(lambda_val)
#      10 for tau in tau_values:
#      11     model = Regressor(model='qr', penalization='lasso', quantile=tau, lambda1=lambda_val)
# ---> 13     model.fit(train_X, train_Y)
#      14     y_pred_test = model.predict(test_X).reshape(-1, 1)
#      15     test_predictions.append(y_pred_test)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\asgl\skmodels.py:579, in Regressor.fit(self, X, y, group_index)
#     577     self.fit_weights(X, y, group_index)
#     578 # Call the fit method of the parent class (BaseModel) to perform the main fitting logic.
# --> 579 super().fit(X, y, group_index)
#     580 return self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\asgl\skmodels.py:200, in BaseModel.fit(self, X, y, group_index)
#     198         raise ValueError(f"group_index must be a positive integer array. Negative values detected")
#     199 # Solve the problem
# --> 200 self.intercept_, self.coef_ = self._obtain_beta(X, y, group_index)
#     201 self.is_fitted_ = True
#     202 return self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\asgl\skmodels.py:164, in BaseModel._obtain_beta(self, X, y, group_index)
#     162     pen = getattr(self, '_' + self.penalization)(beta_var, group_index)
#     163     problem = cp.Problem(cp.Minimize(objective_function + pen))
# --> 164 self._solve_cp_problem(problem)
#     165 beta_sol = beta_var.value
#     166 intercept_sol = intercept_var.value if self.fit_intercept else 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\asgl\skmodels.py:95, in BaseModel._solve_cp_problem(self, problem)
#      93 chosen_solver = self.solver if self.solver != 'default' else None # Let cp choose default
#      94 try:
# ---> 95     problem.solve(solver=chosen_solver)
#      96 except (ValueError, cp.error.SolverError, cp.error.DCPError):
#      97     warnings.warn(f'Default solver {self.solver} failed. Using alternative options from {solver_options}',
#      98                   RuntimeWarning, stacklevel=2)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cvxpy\problems\problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cvxpy\problems\problem.py:1218, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1216     # Cite solver.
#    1217     print(solving_chain.reductions[-1].cite(data))
# -> 1218 solution = solving_chain.solve_via_data(
#    1219     self, data, warm_start, solver_verbose, kwargs)
#    1220 end = time.time()
#    1221 self._solve_time = end - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:481, in SolvingChain.solve_via_data(self, problem, data, warm_start, verbose, solver_opts)
#     445 def solve_via_data(self, problem, data, warm_start: bool = False, verbose: bool = False,
#     446                    solver_opts={}):
#     447     """Solves the problem using the data output by the an apply invocation.
#     448
#     449     The semantics are:
#    (...)    479         a Solution object.
#     480     """
# --> 481     return self.solver.solve_via_data(data, warm_start, verbose,
#     482                                       solver_opts, problem._solver_cache)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\cvxpy\reductions\solvers\conic_solvers\clarabel_conif.py:352, in CLARABEL.solve_via_data(self, data, warm_start, verbose, solver_opts, solver_cache)
#     349 if solver is None:
#     350     solver = new_solver()
# --> 352 results = solver.solve()
#     354 if solver_cache is not None:
#     355     solver_cache[self.name()] = solver
#
# KeyboardInterrupt:

# %%
columns = [f'q{int(tau * 100)}' for tau in tau_values]
all_pred_df = pd.DataFrame(test_predictions_matrix, columns=columns)
all_pred_df.to_excel('lassopredf.xlsx', index=False)

# %%
all_pred_df
# Out:
#             q5       q10       q15       q20       q25       q30       q35  \
# 0    -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 1    -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 2    -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 3    -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 4    -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# ...        ...       ...       ...       ...       ...       ...       ...
# 1137 -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 1138 -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 1139 -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 1140 -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
# 1141 -0.310128  0.205342  1.289874  2.639963  4.199869  5.909996  7.500842
#
#            q40        q45        q50        q55        q60        q65  \
# 0     8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 1     8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 2     8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 3     8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 4     8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# ...        ...        ...        ...        ...        ...        ...
# 1137  8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 1138  8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 1139  8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 1140  8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
# 1141  8.899923  10.550243  12.189979  14.010023  15.680613  17.350133
#
#             q70        q75        q80        q85        q90        q95
# 0     19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 1     19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 2     19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 3     19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 4     19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# ...         ...        ...        ...        ...        ...        ...
# 1137  19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 1138  19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 1139  19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 1140  19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
# 1141  19.440044  21.615531  24.030022  26.620795  29.180955  32.887342
#
# [1142 rows x 19 columns]
